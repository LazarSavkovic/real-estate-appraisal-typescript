# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# %%
# Opening JSON file
with open('apartments.json') as json_file:
    apartments = json.load(json_file)
 
    # Print the type of data variable
    print("Type:", type(data))
# Out:
# Type: <class 'list'>

# %%
apts = []
for apartment in apartments:
    apt = {}
    apt["lat"] = apartment["lat"]
    apt["long"] = apartment["long"]
    apt["date"] = apartment["date"]
    apt["sq_mt"] = apartment["sq_mt"]
    apt["rooms"] = apartment["rooms"]
    apt["price"] = apartment["price"]
    apts.append(apt)

# %%
apt_df =pd.DataFrame(apts)

# %%
plt.plot(apt_df.long, apt_df.lat, ".")

# %%
X = apt_df.drop(["price", "date"], axis=1).to_numpy()

# %%
y = apt_df.price.to_numpy()

# %%
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   random_state = 0)
linreg = LinearRegression().fit(X_train, y_train)

print('linear model coeff (w): {}'
     .format(linreg.coef_))
print('linear model intercept (b): {:.3f}'
     .format(linreg.intercept_))
print('R-squared score (training): {:.3f}'
     .format(linreg.score(X_train, y_train)))
print('R-squared score (test): {:.3f}'
     .format(linreg.score(X_test, y_test)))
# Out:
# linear model coeff (w): [755932.22948542 -66040.42558601   5560.98988887 -75298.14989166]
# linear model intercept (b): -32528665.189
# R-squared score (training): 0.736
# R-squared score (test): 0.085

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

from sklearn.linear_model import Ridge
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   random_state = 0)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

linridge = Ridge(alpha=20.0).fit(X_train_scaled, y_train)

print('Crime dataset')
print('ridge regression linear model intercept: {}'
     .format(linridge.intercept_))
print('ridge regression linear model coeff:\n{}'
     .format(linridge.coef_))
print('R-squared score (training): {:.3f}'
     .format(linridge.score(X_train_scaled, y_train)))
print('R-squared score (test): {:.3f}'
     .format(linridge.score(X_test_scaled, y_test)))
print('Number of non-zero features: {}'
     .format(np.sum(linridge.coef_ != 0)))
# Out:
# Crime dataset
# ridge regression linear model intercept: 61891.73387593456
# ridge regression linear model coeff:
# [ 24005.64101676   3699.59139047 232977.1258961  220715.80653402]
# R-squared score (training): 0.303
# R-squared score (test): 0.517
# Number of non-zero features: 4

# %%
print('Ridge regression: effect of alpha regularization parameter\n')
for this_alpha in [0, 1, 10, 20, 50, 100, 1000]:
    linridge = Ridge(alpha = this_alpha).fit(X_train_scaled, y_train)
    r2_train = linridge.score(X_train_scaled, y_train)
    r2_test = linridge.score(X_test_scaled, y_test)
    num_coeff_bigger = np.sum(abs(linridge.coef_) > 1.0)
    print('Alpha = {:.2f}\nnum abs(coeff) > 1.0: {}, \
r-squared training: {:.2f}, r-squared test: {:.2f}\n'
         .format(this_alpha, num_coeff_bigger, r2_train, r2_test))
linridge.coef_
# Out:
# Ridge regression: effect of alpha regularization parameter
#
# Alpha = 0.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.87, r-squared test: 0.29
#
# Alpha = 1.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.77, r-squared test: 0.31
#
# Alpha = 10.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.59, r-squared test: 0.57
#
# Alpha = 20.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.50, r-squared test: 0.57
#
# Alpha = 50.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.38, r-squared test: 0.56
#
# Alpha = 100.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.30, r-squared test: 0.50
#
# Alpha = 1000.00
# num abs(coeff) > 1.0: 14, r-squared training: 0.06, r-squared test: 0.08
# array([    0.        ,   411.40938346,   329.11302064,  6616.12592218,
#         9449.98775349,   411.12901564,   730.33533357,  6615.79634563,
#         9443.24938275,   323.99811762,  6615.24394451,  9433.6712031 ,
#         5130.55912558,  6945.07491778, 10564.63425003])

# %%
linridge = Ridge(alpha = 10).fit(X_train_scaled, y_train)
r2_train = linridge.score(X_train_scaled, y_train)
r2_test = linridge.score(X_test_scaled, y_test)
predictions = linridge.predict(X_test_scaled)

# %%
new_df = pd.DataFrame()

# %%
new_df["predictions"] = predictions
new_df["y_test"] = y_test

# %%
new_df.head(50)
# Out:
#       predictions  y_test
# 0   249711.521061  179000
# 1   189371.711292  104000
# 2   122656.464569  100000
# 3   252126.426396  189000
# 4   288447.266699  270000
# 5   462795.935742  355000
# 6   110892.366235  159000
# 7   114329.263655  120000
# 8   109045.602240   45000
# 9   225798.421176  235000
# 10  311602.056088  215000
# 11  361407.626163  396000
# 12  191033.492421  149000
# 13  239112.513221   91200
# 14  165502.727714   96800
# 15  194181.568972  185000
# 16  182517.558755  219900
# 17  850844.017114  600000
# 18  394166.795341  417270
# 19  110217.596428  125000
# 20  155777.643351  151000
# 21  201564.561026  165000
# 22  226139.635387  260000
# 23  218392.237016  162800
# 24   77351.257527   43900
# 25  189434.730866  170000
# 26   61465.493790   88000
# 27  451207.070756  280000
# 28  149525.750785  276888
# 29  128304.857200  138000
# 30  507033.283033  320000
# 31  479752.113911  225000
# 32  157055.955861   98800
# 33  790290.450401  690000
# 34  182738.630698  305000
# 35   67404.702693   62731
# 36   74006.278550   76000
# 37  342228.487099  275000
# 38  297364.630325  139000
# 39  201718.799487  136500
# 40   92772.403102   90000
# 41  401625.451248  560000
# 42   11535.575569    1100
# 43  310291.160894  165000
# 44  150428.988322   54000
# 45  194351.442535  117000
# 46  165961.541239  149900
# 47  157121.281168  190000
# 48  391977.512635  250000
# 49  368837.609517  210000
